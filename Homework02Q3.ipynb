# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

"""
np.random.normal parameters : (loc, scale, size) where 
loc = mean/the center of the distribution 
scale = standard deviation/width of the distribution
size = output shape of the returned array
"""

# for a normal/gaussian distribution with the mean 100.0, standard deviation 50.0 with size 10000:

incomes = np.random.normal(100.0, 50.0, 10000)

#bins = how many groups the data will be sorted into

plt.hist(incomes, bins = 50)
plt.show()

# %%
# computing the standard deviation of the given data  with the formula sqrt(mean(abs(x-x.mean( ))**2:
incomes.std()
# Out:
# 50.547405052080315

# %%
# computing the variance of the given data with the formula var = mean(abs(x - x.mean())^2)
incomes.var()
# Out:
# 2555.0401574990747

# %%
"""
drawing samples from a uniform distribution with the syntax (low, high, size)
low = lower boundary of the output interval
high = higher boundary of the output interval
size = output shape, if the shape is (a,b,c) then a*b*c samples are drawn. 
"""

values = np.random.uniform(-10.0, 10.0, 100000)
plt.hist(values, bins = 50)
# Out:
# (array([2067., 2057., 1996., 1985., 1925., 2074., 2027., 1987., 2004.,
#         2017., 2005., 2005., 2013., 1995., 1971., 2051., 1979., 1965.,
#         1984., 2031., 2000., 2091., 2010., 1991., 1979., 2038., 1991.,
#         1882., 2051., 1999., 2053., 1984., 1996., 2000., 1990., 1974.,
#         1952., 1955., 2014., 1925., 2000., 1970., 1913., 2024., 1937.,
#         1990., 1991., 2034., 2077., 2051.]),
#  array([-9.99987627e+00, -9.59989175e+00, -9.19990723e+00, -8.79992271e+00,
#         -8.39993819e+00, -7.99995367e+00, -7.59996915e+00, -7.19998463e+00,
#         -6.80000011e+00, -6.40001559e+00, -6.00003107e+00, -5.60004655e+00,
#         -5.20006203e+00, -4.80007751e+00, -4.40009299e+00, -4.00010847e+00,
#         -3.60012395e+00, -3.20013943e+00, -2.80015491e+00, -2.40017039e+00,
#         -2.00018587e+00, -1.60020135e+00, -1.20021683e+00, -8.00232307e-01,
#         -4.00247787e-01, -2.63266659e-04,  3.99721254e-01,  7.99705774e-01,
#          1.19969029e+00,  1.59967481e+00,  1.99965933e+00,  2.39964385e+00,
#          2.79962838e+00,  3.19961290e+00,  3.59959742e+00,  3.99958194e+00,
#          4.39956646e+00,  4.79955098e+00,  5.19953550e+00,  5.59952002e+00,
#          5.99950454e+00,  6.39948906e+00,  6.79947358e+00,  7.19945810e+00,
#          7.59944262e+00,  7.99942714e+00,  8.39941166e+00,  8.79939618e+00,
#          9.19938070e+00,  9.59936522e+00,  9.99934974e+00]),
#  <BarContainer object of 50 artists>)

# %%
"""
arange function is a function that returns an array containing evenly spaced values within an interval.
np.arange(start, stop, step)
start = start of interval
stop = stop of interval
step = spacing between values
"""

x = np.arange(-3, 3, 0.001)

# to plot the probability density function of a normal continous distribution: 

plt.plot(x, norm.pdf(x))

# %%
#defining values mu and sigma outside of the function:

mu = 5.0
sigma = 2.0
vals = np.random.normal(mu, sigma, 10000)
plt.hist(vals, 50)
plt.show()
